# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %% [markdown]
# test development for autoencoder.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'), 
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2D(filters = 256, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (1, 5), strides = (1, 1), padding='same',
                        activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2D(filters = 512, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    tf.keras.layers.Conv2D(filters = 512, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2D(filters = 512, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2D(filters = 1024, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2D(filters = 1024, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    
    tf.keras.layers.Conv2D(filters = 1024, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),


    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=200, activation='LeakyReLU', use_bias=False),
    tf.keras.layers.Dense(units=20, activation=None, use_bias=False, name = 'bottleneck'),
    tf.keras.layers.Dense(units=200, activation='LeakyReLU', use_bias=False),
    tf.keras.layers.Dense(units=524288, activation='LeakyReLU', use_bias=False),
    tf.keras.layers.Reshape((64, 8, 1024)),

    
    tf.keras.layers.Conv2DTranspose(filters = 1024, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 1024, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    
    tf.keras.layers.Conv2DTranspose(filters = 1024, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    
    tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    
    tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (1, 5), strides = (1, 1), padding='same', 
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),
    
    tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (1, 5), strides = (1, 1), padding='same', 
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (1, 5), strides = (1, 1), padding='same', 
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (1, 5), strides = (1, 2), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),

    tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (1, 5), strides = (1, 1), padding='same',
                           activation=None, use_bias = False, kernel_initializer='he_uniform'),
    tf.keras.layers.LeakyReLU(alpha=0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.SpatialDropout2D(rate=0.2),


    tf.keras.layers.Conv2D(1, kernel_size=(1, 5), strides = (1, 1), padding='same',
                           activation='tanh', use_bias = False, kernel_initializer='he_uniform')

])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 64, 256, 64)       320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64, 256, 64)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 256, 64)       256
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 64, 256, 64)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 256, 64)       20480
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 256, 64)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 256, 64)       256
# ...
